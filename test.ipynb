# %%
from tools import getSoup

# %% [markdown]
# ### 發票對獎程式

# %%
url = 'https://invoice.etax.nat.gov.tw/'

# %%
soup = getSoup(url)
soup
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
# <head>
# <!-- Google Analytics -->
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-1RL7V80ELX"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-1RL7V80ELX');
#     </script>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=device-width,initial-scale=1, user-scalable=no" name="viewport"/>
# <title>財政部稅務入口網</title>
# <link href="images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!-- CSS_JS -->
# <link href="css/bootstrap.css" rel="stylesheet"/>
# <!-- CSS -->
# <link href="css/global.css" rel="stylesheet"/>
# <link href="css/inner.css" rel="stylesheet"/>
# <!-- JS -->
# <script src="js/jquery.min.js" type="text/javascript"></script>
# <script src="js/bootstrap.js" type="text/javascript"></script>
# </head>
# <body>
# <!-- page -->
# <div class="etw-page">
# <!-- wrapper -->
# <div class="etw-wrapper">
# <a class="etw-pagetab" href="#area_main" tabindex="1" title="跳到主要內容">跳到主要內容</a>
# <div class="etw-header etw-header_invoice">
# <div class="etw-header_down align-items-center container-xl">
# <a class="etw-logo" href="index.html" title="首頁"><h1><img alt="" src="images/logo_01.png"/></h1></a>
# <div class="etw-header_menu">
# <a accesskey="U" class="etw-accesskey" href="#header" title="上方區域">:::</a>
# <ul>
# <li><a href="https://www.etax.nat.gov.tw/etwmain/etw183w" title="中文版">中文版</a></li>
# <li><a href="https://www.etax.nat.gov.tw/etwmain/en/etw183w" title="ENGLISH">ENGLISH</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="etw-page-nav etw-mflex" id="etw-page-nav">
# <div class="container-xl">
# <a accesskey="N" class="etw-accesskey" href="#pageNav" title="選單區域">:::</a>
# <!-- 選單 -->
# <ul class="etw-page-nav_links etw-inline">
# <li><a class="etw-link" href="#" title="統一發票號碼獎中獎號碼">統一發票號碼獎中獎號碼</a></li>
# <li><a class="" href="cloudNowNumber.html" title="雲端發票專屬獎中獎號碼">雲端發票專屬獎中獎號碼</a></li>
# <li><a href="https://www.etax.nat.gov.tw/etwmain/etw700w" title="發票號碼中獎查詢">發票號碼中獎查詢</a></li>
# </ul>
# </div>
# </div>
# <!-- container -->
# <div class="etw-container" id="etw-container">
# <div class="container-xl">
# <a accesskey="C" class="etw-accesskey" href="#container" title="內容區域">:::</a>
# <!-- 次選單01 -->
# <div class="etw-web">
# <ul class="etw-submenu etw-submenu01">
# <li><a class="etw-on" href="index.html" title="112年07-08月中獎號碼單">112年07-08月中獎號碼單</a></li>
# <li><a href="list1.html" title="112年07-08月特別獎、特獎中獎清冊">112年07-08月特別獎、特獎中獎清冊</a></li>
# <li><a href="lastNumber.html" title="112年05-06月中獎號碼單">112年05-06月中獎號碼單</a></li>
# <li><a href="list2.html" title="112年05-06月特別獎、特獎中獎清冊">112年05-06月特別獎、特獎中獎清冊</a></li>
# </ul>
# </div>
# <div class="etw-mobile">
# <div class="carousel slide etw-submenu etw-submenu01" data-ride="carousel" id="submenu01">
# <a class="carousel-control-prev" data-slide="prev" href="#submenu01" role="button">
# <span aria-hidden="true" class="carousel-control-prev-icon"></span>
# <span class="sr-only">Previous</span>
# </a>
# <div class="carousel-inner">
# <div class="carousel-item active"><a class="etw-on" href="index.html" title="112年07-08月中獎號碼單">112年07-08月中獎號碼單</a></div>
# <div class="carousel-item"><a href="list1.html" title="112年07-08月特別獎、特獎中獎清冊">112年07-08月特別獎、特獎中獎清冊</a></div>
# <div class="carousel-item"><a href="lastNumber.html" title="112年05-06月中獎號碼單">112年05-06月中獎號碼單</a></div>
# <div class="carousel-item"><a href="list2.html" title="112年05-06月特別獎、特獎中獎清冊">112年05-06月特別獎、特獎中獎清冊</a></div>
# </div>
# <a class="carousel-control-next" data-slide="next" href="#submenu01" role="button">
# <span aria-hidden="true" class="carousel-control-next-icon"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# </div>
# <!-- content -->
# <div class="container-fluid etw-bgbox mb-4">
# <div class="etw-web">
# <table class="etw-table-bgbox etw-tbig">
# <thead>
# <tr>
# <th id="th01" width="30%">獎別</th>
# <th id="th02">中獎號碼</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="text-center" headers="th01">特別獎</td>
# <td headers="th02">
# <p class="etw-tbiggest"><span class="font-weight-bold etw-color-red">21981893</span></p>
# <p class="mb-0">同期統一發票收執聯8位數號碼與特別獎號碼相同者獎金1,000萬元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center" headers="th01">特獎</td>
# <td headers="th02">
# <p class="etw-tbiggest"><span class="font-weight-bold etw-color-red">39597522</span></p>
# <p class="mb-0">同期統一發票收執聯8位數號碼與特獎號碼相同者獎金200萬元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center" headers="th01">頭獎</td>
# <td headers="th02">
# <p class="etw-tbiggest mb-md-4">
# <span class="font-weight-bold">09505</span><span class="font-weight-bold etw-color-red">831</span></p>
# <p class="etw-tbiggest mb-md-4">
# <span class="font-weight-bold">54219</span><span class="font-weight-bold etw-color-red">897</span></p>
# <p class="etw-tbiggest mb-md-4">
# <span class="font-weight-bold">17469</span><span class="font-weight-bold etw-color-red">638</span></p>
# <p class="mb-0">同期統一發票收執聯8位數號碼與頭獎號碼相同者獎金20萬元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center" headers="th01">二獎</td>
# <td headers="th02">
# <p class="mb-0">同期統一發票收執聯末7 位數號碼與頭獎中獎號碼末7 位相同者各得獎金4萬元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center" headers="th01">三獎</td>
# <td headers="th02">
# <p class="mb-0">同期統一發票收執聯末6 位數號碼與頭獎中獎號碼末6 位相同者各得獎金1萬元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center" headers="th01">四獎</td>
# <td headers="th02">
# <p class="mb-0">同期統一發票收執聯末5 位數號碼與頭獎中獎號碼末5 位相同者各得獎金4千元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center" headers="th01">五獎</td>
# <td headers="th02">
# <p class="mb-0">同期統一發票收執聯末4 位數號碼與頭獎中獎號碼末4 位相同者各得獎金1千元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center" headers="th01">六獎</td>
# <td headers="th02">
# <p class="mb-0">同期統一發票收執聯末3 位數號碼與 頭獎中獎號碼末3 位相同者各得獎金2百元</p>
# </td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <td class="text-center etw-color-redbrown" colspan="2" headers="th02" scope="col">領獎期間自112年10月06日起至113年01月05日止</td>
# </tr>
# </tfoot>
# </table>
# </div>
# <div class="etw-mobile">
# <table class="etw-table-bgbox etw-tbig">
# <thead>
# <tr>
# <th width="100">獎別</th>
# <th>中獎號碼</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="text-center">特別獎</td>
# <td>
# <p class="etw-tbiggest"><span class="font-weight-bold etw-color-red">21981893</span></p>
# <p class="mb-0">同期統一發票收執聯8位數號碼與特別獎號碼相同者獎金1,000萬元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center">特獎</td>
# <td>
# <p class="etw-tbiggest"><span class="font-weight-bold etw-color-red">39597522</span></p>
# <p class="mb-0">同期統一發票收執聯8位數號碼與特獎號碼相同者獎金200萬元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center">頭獎</td>
# <td>
# <p class="etw-tbiggest mb-md-4">
# <span class="font-weight-bold">09505</span><span class="font-weight-bold etw-color-red">831</span></p>
# <p class="etw-tbiggest mb-md-4">
# <span class="font-weight-bold">54219</span><span class="font-weight-bold etw-color-red">897</span></p>
# <p class="etw-tbiggest mb-md-4">
# <span class="font-weight-bold">17469</span><span class="font-weight-bold etw-color-red">638</span></p>
# <p class="mb-0">同期統一發票收執聯8位數號碼與頭獎號碼相同者獎金20萬元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center">二獎</td>
# <td>
# <p class="mb-0">同期統一發票收執聯末7 位數號碼與頭獎中獎號碼末7 位相同者各得獎金4萬元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center">三獎</td>
# <td>
# <p class="mb-0">同期統一發票收執聯末6 位數號碼與頭獎中獎號碼末6 位相同者各得獎金1萬元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center">四獎</td>
# <td>
# <p class="mb-0">同期統一發票收執聯末5 位數號碼與頭獎中獎號碼末5 位相同者各得獎金4千元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center">五獎</td>
# <td>
# <p class="mb-0">同期統一發票收執聯末4 位數號碼與頭獎中獎號碼末4 位相同者各得獎金1千元</p>
# </td>
# </tr>
# <tr>
# <td class="text-center">六獎</td>
# <td>
# <p class="mb-0">同期統一發票收執聯末3 位數號碼與 頭獎中獎號碼末3 位相同者各得獎金2百元</p>
# </td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <td class="text-center etw-color-redbrown" colspan="2" scope="col">領獎期間自112年10月06日起至113年01月05日止</td>
# </tr>
# </tfoot>
# </table>
# </div>
# </div>
# <div class="row">
# <div class="col-md">
# <div class="etw-bgbox mb-4">
# <div class="etw-bgbox_inner" style="line-height: 160%;">
# <h3 class="etw-boxtitle etw-color-browndark mb-3">領獎注意事項</h3>
# <div>
# <p>1.領獎期間自112年10月6日起至113年1月5日止，中獎人請於領獎期間攜帶國民身分證(非本國國籍人士得以護照、居留證或內政部移民署核發入出境許可證等替代)及中獎統一發票，依代發獎金單位公告之兌獎營業時間臨櫃兌領，逾期不得領獎。<br/>2.統一發票未依規定載明金額者，不得領獎。<br/>3.統一發票買受人為政府機關、公營事業、公立學校、部隊及營業人者，不得領獎。<br/>4.中三獎(含)以上者，依規定應由發獎單位扣繳20﹪所得稅款。<br/>5.中五獎 及雲端發票專屬獎500元（含）以上者，依規定應繳納0.4%印花稅款，但已於財政部電子發票整合服務平台或統一發票兌獎APP設定領獎帳戶兌領獎金者，免繳納印花稅。<br/>6.中獎之統一發票如同時對中多數獎項，以兌領一個獎項為限。<br/>7.詳細領獎規定，請查閱「統一發票給獎辦法」。若有疑義，請洽財金公司客服專線：4128282(手機請撥：02-4128282)，或至財金公司網站查詢。   </p>
# </div>
# <h3 class="etw-boxtitle etw-color-browndark mb-3">統一發票兌獎通路公告</h3>
# <a href="https://www.fisc.com.tw/TC/News/Content?CAID=8c3e35f6-30d4-4a87-9c16-da80241c1be1&amp;CTID=55dcf966-0ed1-4d29-af35-ad72b69a7729">108年1月1日起統一發票兌獎通路公告（連結至財金資訊股份有限公司網頁）</a>
# </div>
# </div>
# </div>
# <div class="col-md">
# <div class="etw-bgbox mb-4">
# <div class="etw-bgbox_inner">
# <h3 class="etw-boxtitle etw-color-browndark mb-4">影片專區</h3>
# <div class="embed-responsive embed-responsive-16by9">
# <iframe allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" class="embed-responsive-item" frameborder="0" src="https://www.youtube.com/embed/xNT-jeOBXuA?rel=0&amp;wmode=transparent" title="兌獎多元服務管道"></iframe>
# </div>
# </div>
# </div>
# <div class="etw-bgbox">
# <div class="etw-bgbox_inner">
# <h3 class="etw-boxtitle etw-color-browndark mb-4">財政部統一發票兌獎APP下載點</h3>
# <div class="row">
# <div class="col-6 col-sm-3 mb-3 mb-sm-0">
# <a class="etw-imgbox etw-color-black text-center" href="#" title="另開視窗至下載網頁">
# <img alt="下載網址QR code" class="mb-2" src="android.jpg"/>
# <p class="mb-0">Android系統</p>
# </a>
# </div>
# <div class="col-6 col-sm-3 mb-3 mb-sm-0">
# <a class="etw-imgbox etw-color-black text-center" href="#" title="另開視窗至下載網頁">
# <img alt="下載網址QR code" class="mb-2" src="ios.jpg"/>
# <p class="mb-0">ios系統</p>
# </a>
# </div>
# <div class="col-6 col-sm-3">
# <a class="etw-imgbox etw-color-black text-center" href="#" title="另開視窗至下載網頁">
# <img alt="下載網址QR code" class="mb-2" src="etw.jpg"/>
# <p class="mb-0">稅務入口網</p>
# </a>
# </div>
# <div class="col-6 col-sm-3">
# <a class="etw-imgbox etw-color-black text-center" href="#" title="另開視窗至下載網頁">
# <img alt="下載網址QR code" class="mb-2" src="etwweb.jpg"/>
# <p class="mb-0">財金公司網站</p>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- pagebtn -->
# <div class="etw-pagebtn">
# <div class="container-xl">
# <a class="etw-pagebtn_top" href="#"><span>Top</span></a>
# </div>
# </div>
# <!-- footer -->
# <div class="etw-footer" id="etw-footer">
# <div class="etw-footer_inner etw-nonav container-xl">
# <a accesskey="Z" class="etw-accesskey" href="#footer" title="下方區域">:::</a>
# <div class="container-xl">
# <div class="etw-footer_info">
# <a class="etw-logo" href="#" target="_blank" title="另開視窗連結至無障礙網站"><img alt="logo" src="images/logo_01.png"/></a>
# <div class="etw-footer_info_text">
# <p><span>地址：11002 臺北市信義區忠孝東路四段547號</span><span>國稅及地方稅免付費電話: 0800-000-321</span>
# </p>
# <p><span>網站操作免付費諮詢電話: 0800-080-369 <br class="etw-mobile"/>(周一至周五09:00至18:00 例假日除外)</span><span class="etw-updatetime">更新日期：112-10-04</span></p>
# </div>
# <div class="etw-footer_info_emblem">
# <a href="#" target="_blank" title="另開視窗連結至無障礙網站"><img alt="" src="images/logo_other_02.png"/></a>
# <a href="#" target="_blank" title="另開視窗連結至GOV網站"><img alt="" src="images/logo_other_01.png"/></a>
# </div>
# </div>
# </div>
# </div>
# <div class="etw-footer_copyright">
# <div class="container-xl">
# <p class="etw-footer_copyright_text"><span>Copyright © 2021 財政部財政資訊中心</span><br/><span>最佳瀏覽解析度 1280 x 800 畫素 </span><span class="etw-br">建議使用 Chrome 或 Edge 瀏覽器</span></p>
# <ul class="etw-footer_copyright_link">
# <li><a href="#" title="隱私權政策">隱私權政策</a></li>
# <li><a href="#" title="資訊安全政策">資訊安全政策</a></li>
# <li><a href="#" title="政府網站資料開放宣告">政府網站資料開放宣告</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </body>
# </html>

# %%
trs = soup.find('table',class_="etw-table-bgbox etw-tbig").find_all('tr')
trs
# Out:
# [<tr>
#  <th id="th01" width="30%">獎別</th>
#  <th id="th02">中獎號碼</th>
#  </tr>,
#  <tr>
#  <td class="text-center" headers="th01">特別獎</td>
#  <td headers="th02">
#  <p class="etw-tbiggest"><span class="font-weight-bold etw-color-red">21981893</span></p>
#  <p class="mb-0">同期統一發票收執聯8位數號碼與特別獎號碼相同者獎金1,000萬元</p>
#  </td>
#  </tr>,
#  <tr>
#  <td class="text-center" headers="th01">特獎</td>
#  <td headers="th02">
#  <p class="etw-tbiggest"><span class="font-weight-bold etw-color-red">39597522</span></p>
#  <p class="mb-0">同期統一發票收執聯8位數號碼與特獎號碼相同者獎金200萬元</p>
#  </td>
#  </tr>,
#  <tr>
#  <td class="text-center" headers="th01">頭獎</td>
#  <td headers="th02">
#  <p class="etw-tbiggest mb-md-4">
#  <span class="font-weight-bold">09505</span><span class="font-weight-bold etw-color-red">831</span></p>
#  <p class="etw-tbiggest mb-md-4">
#  <span class="font-weight-bold">54219</span><span class="font-weight-bold etw-color-red">897</span></p>
#  <p class="etw-tbiggest mb-md-4">
#  <span class="font-weight-bold">17469</span><span class="font-weight-bold etw-color-red">638</span></p>
#  <p class="mb-0">同期統一發票收執聯8位數號碼與頭獎號碼相同者獎金20萬元</p>
#  </td>
#  </tr>,
#  <tr>
#  <td class="text-center" headers="th01">二獎</td>
#  <td headers="th02">
#  <p class="mb-0">同期統一發票收執聯末7 位數號碼與頭獎中獎號碼末7 位相同者各得獎金4萬元</p>
#  </td>
#  </tr>,
#  <tr>
#  <td class="text-center" headers="th01">三獎</td>
#  <td headers="th02">
#  <p class="mb-0">同期統一發票收執聯末6 位數號碼與頭獎中獎號碼末6 位相同者各得獎金1萬元</p>
#  </td>
#  </tr>,
#  <tr>
#  <td class="text-center" headers="th01">四獎</td>
#  <td headers="th02">
#  <p class="mb-0">同期統一發票收執聯末5 位數號碼與頭獎中獎號碼末5 位相同者各得獎金4千元</p>
#  </td>
#  </tr>,
#  <tr>
#  <td class="text-center" headers="th01">五獎</td>
#  <td headers="th02">
#  <p class="mb-0">同期統一發票收執聯末4 位數號碼與頭獎中獎號碼末4 位相同者各得獎金1千元</p>
#  </td>
#  </tr>,
#  <tr>
#  <td class="text-center" headers="th01">六獎</td>
#  <td headers="th02">
#  <p class="mb-0">同期統一發票收執聯末3 位數號碼與 頭獎中獎號碼末3 位相同者各得獎金2百元</p>
#  </td>
#  </tr>,
#  <tr>
#  <td class="text-center etw-color-redbrown" colspan="2" headers="th02" scope="col">領獎期間自112年10月06日起至113年01月05日止</td>
#  </tr>]

# %%
for tr in trs[1:4] :
    for td in tr.find_all('td'):
        print(td.text.strip(),end='\t')
    print()
# Out:
# 特別獎	21981893
# 同期統一發票收執聯8位數號碼與特別獎號碼相同者獎金1,000萬元
# 特獎	39597522
# 同期統一發票收執聯8位數號碼與特獎號碼相同者獎金200萬元
# 頭獎	09505831
#
# 54219897
#
# 17469638
# 同期統一發票收執聯8位數號碼與頭獎號碼相同者獎金20萬元

# %%
datas = [ [td.text.strip() for td in tr.find_all('td')] for tr in trs[1:4]]

# %%
numbers = []
for data in datas:
    print(data[1].split()[:-1])
    numbers+=data[1].split()[:-1]
numbers
# Out:
# ['21981893']
# ['39597522']
# ['09505831', '54219897', '17469638']
# ['21981893', '39597522', '09505831', '54219897', '17469638']

# %%
while True:
    invoice_number = '21981831'
    bingo = False
    for i in range(len(numbers)) :
        
        if i == 0 or i ==1:
            if numbers[i] == invoice_number:
                bingo = True
        else:
            if numbers[i][5:] == invoice_number[5:]:
                bingo = True
        if bingo:
            break
        if bingo:
            if i==0:
                print(f'恭喜中特別獎1000W:{invoice_number}')
            elif i==1:
                print(f'恭喜中頭獎200w:{invoice_number}')
            else:
                print(f'恭喜中頭獎(至少中200):{invoice_number}')
# Out:
# (2, True)
